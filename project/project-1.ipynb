# %% [markdown]
# # Ranking hotels by the number of top attraction around them
#
# **IBM Data Science Professional Certificate Specialization Capstone Project**

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
#     1. [Description of the Problem](#Description-of-the-Problem)
#     2. [Description of the Data](#Description-of-the-Data)
# 2. Methodology
#     1. [Overview](#Methodology)
#     2. [The list of categories](#The-list-of-categories)
#     3. [The most popular local attractions](#The-most-popular-local-attractions)
#     4. [The most popular hotels](#The-most-popular-hotels)
#     5. [The most popular local attracation around the most popular hotels](#The-most-popular-local-attracation-around-the-most-popular-hotels)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Description of the Problem

# %% [markdown]
# Finding the best hotel for a short stay might be tricky. On one hand, one wants to stay in a nice place, on the other, wishes to experience the local culture as much as possible.
#
# Following report explores the feasibility of locating the best possible hotel within range of as many local attractions as possible. For the sake of the exercise the top 10 hotels in the city of Prague in Czech Republic is used.
#
# **Target audience**:
# - End users: with a bit of technical knowledge the approach can be utilized to identify the hotel in the city of ones choice.
# - Investors: the approach can be implemented in any travel-related app

# %% [markdown]
# ### Description of the Data

# %% [markdown]
# The Foursquare API is used to fetch all required data:
# - The list of categories supported by Foursquare. (Endpoint: categories)
# - The list of the most popular local attractions in a given city. (Endpoint: explore)
# - The list of the most popular hotels amongst Foursqaure users. (Endpoint: search)
# - The list of the most popular local attracation around the listed hotels. (Endpoint: search)
#
# The categories IDs from the list of categories can be used in the further API calls to Foursquare to filter results correctly.
#
# The list of the most popular local attractions in a given city is the first of two main datasets.
#
# The list of the most popular hotels is joined with the lists of the most popular attractions around each of them. This creates the second of two main datasets.
#
# The main datasets are then used to to rank the hotels by the number of the top attractions around them.

# %% [markdown]
# ## Methodology
#
# Following section describes in the details the datasets utilized in the report
#
# For fetching the data a python library "requests" is used. And for storing and manipulating the data - Pandas library.
#
# Following global variables are defined for the HTTP requests

# %%
import os

CLIENT_ID = os.environ['CAPSTONE_FOURSQUARE_CLIENT_ID'] # Foursquare Client ID
CLIENT_SECRET = os.environ['CAPSTONE_FOURSQUARE_CLIENT_SECRET'] # Foursquare Client Secret
VERSION = '20180605' # Foursquare API version
DEFAULT_NEAR = 'Prague, Czech Republic' # City of interest

# %%
import requests
import pandas as pd

# %% [markdown]
# ### The categories

# %% [markdown]
# The endpoint _categories_ returns a hierarchical list of Foursquare categories, full API reference can be found here https://developer.foursquare.com/docs/api/venues/categories
#
# The endpoint returns a JSON response and each category level is stored in an array named _category_.
#
# The tree structure is converted to the table format containing the ID for category, the full path, and each level name.

# %% [markdown]
# **Fetching and parsing the data**

# %%
data = []

url = 'https://api.foursquare.com/v2/venues/categories?client_id={}&client_secret={}&v={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION
)

response = requests.get(url).json()['response']

for level1 in response['categories']:
    data.append((
        level1['id'],
        level1['name'],
        level1['name'],
        '',
        ''
    ))
    
    for level2 in level1['categories']:
        data.append((
            level2['id'],
            level1['name'] + ' - ' + level2['name'],
            level1['name'],
            level2['name'],
            ''
        ))
        
        for level3 in level2['categories']:
            data.append((
                level3['id'],
                level1['name'] + ' - ' + level2['name'] + ' - ' + level3['name'],
                level1['name'],
                level2['name'],
                level3['name']
            ))
            
categories = pd.DataFrame(data, columns = [
    'Category Id', 
    'Category Path', 
    'Category Level 1', 
    'Category Level 2', 
    'Category Level 3'
])

# %%
print("Shape of the dataframe", categories.shape)
# Out:
# Shape of the dataframe (833, 5)

# %%
categories.head(10)
# Out:
#                 Category Id                         Category Path  \
# 0  4d4b7104d754a06370d81259                  Arts & Entertainment
# 1  56aa371be4b08b9a8d5734db   Arts & Entertainment - Amphitheater
# 2  4fceea171983d5d06c3e9823       Arts & Entertainment - Aquarium
# 3  4bf58dd8d48988d1e1931735         Arts & Entertainment - Arcade
# 4  4bf58dd8d48988d1e2931735    Arts & Entertainment - Art Gallery
# 5  4bf58dd8d48988d1e4931735  Arts & Entertainment - Bowling Alley
# 6  4bf58dd8d48988d17c941735         Arts & Entertainment - Casino
# 7  52e81612bcbc57f1066b79e7         Arts & Entertainment - Circus
# 8  4bf58dd8d48988d18e941735    Arts & Entertainment - Comedy Club
# 9  5032792091d4c4b30a586d5c   Arts & Entertainment - Concert Hall
#
#        Category Level 1 Category Level 2 Category Level 3
# 0  Arts & Entertainment
# 1  Arts & Entertainment     Amphitheater
# 2  Arts & Entertainment         Aquarium
# 3  Arts & Entertainment           Arcade
# 4  Arts & Entertainment      Art Gallery
# 5  Arts & Entertainment    Bowling Alley
# 6  Arts & Entertainment           Casino
# 7  Arts & Entertainment           Circus
# 8  Arts & Entertainment      Comedy Club
# 9  Arts & Entertainment     Concert Hall

# %% [markdown]
# Quick inspection of the data shows that there are 833 categories.
#
# Let's try to identify the category ID for hotels

# %%
categories[categories['Category Path'].str.contains('Hotel')]
# Out:
#                   Category Id                                 Category Path  \
# 384  4bf58dd8d48988d1d5941735              Nightlife Spot - Bar - Hotel Bar
# 802  4bf58dd8d48988d1fa931735                    Travel & Transport - Hotel
# 803  4bf58dd8d48988d1f8931735  Travel & Transport - Hotel - Bed & Breakfast
# 804  4f4530a74b9074f6e4fb0100   Travel & Transport - Hotel - Boarding House
# 805  4bf58dd8d48988d1ee931735           Travel & Transport - Hotel - Hostel
# 806  4bf58dd8d48988d132951735       Travel & Transport - Hotel - Hotel Pool
# 807  5bae9231bedf3950379f89cb              Travel & Transport - Hotel - Inn
# 808  4bf58dd8d48988d1fb931735            Travel & Transport - Hotel - Motel
# 809  4bf58dd8d48988d12f951735           Travel & Transport - Hotel - Resort
# 810  56aa371be4b08b9a8d5734e1  Travel & Transport - Hotel - Vacation Rental
#
#        Category Level 1 Category Level 2 Category Level 3
# 384      Nightlife Spot              Bar        Hotel Bar
# 802  Travel & Transport            Hotel
# 803  Travel & Transport            Hotel  Bed & Breakfast
# 804  Travel & Transport            Hotel   Boarding House
# 805  Travel & Transport            Hotel           Hostel
# 806  Travel & Transport            Hotel       Hotel Pool
# 807  Travel & Transport            Hotel              Inn
# 808  Travel & Transport            Hotel            Motel
# 809  Travel & Transport            Hotel           Resort
# 810  Travel & Transport            Hotel  Vacation Rental

# %% [markdown]
# As the search results shows there are multiple matching tuples: there is a seperate category for hotel bar and multiple different types of hotels and their facilities.
#
# However, the entry in the 2nd row is the one the most interesting as it is the general _Hotel_ category

# %%
categories.iloc[[802]]
# Out:
#                   Category Id               Category Path    Category Level 1  \
# 802  4bf58dd8d48988d1fa931735  Travel & Transport - Hotel  Travel & Transport
#
#     Category Level 2 Category Level 3
# 802            Hotel

# %% [markdown]
# ### The most popular local attractions
#
# The endpoint _explore_ is used to fetch the data, full API reference cen be found here: https://developer.foursquare.com/docs/api/venues/explore
#
# The endpoint returns a JSON response with object _groups_ containing an array _items_ with the list of recommended places.
#
# The data which is the most interesting is:
# - Venue ID
# - Venue Name
# - Venue Location: Latitude and Longitude
# - Venue Category
#
# This list is the list of *the most popular local attracation in the city*.

# %% [markdown]
# **Fetching and parsing the data**

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&limit=100&near={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    DEFAULT_NEAR
)

results = requests.get(url).json()["response"]['groups'][0]['items']
        
data = [(
    v['venue']['id'],
    v['venue']['name'], 
    v['venue']['location']['lat'], 
    v['venue']['location']['lng'],  
    v['venue']['categories'][0]['name']
) for v in results]

most_popular_attractions = pd.DataFrame(data, columns = [
    'Venue Id', 
    'Venue Name', 
    'Venue Latitude', 
    'Venue Longitude', 
    'Venue Category'
])

# %%
print("Shape of the dataframe", most_popular_attractions.shape)
# Out:
# Shape of the dataframe (100, 5)

# %%
most_popular_attractions.head(10)
# Out:
#                    Venue Id                  Venue Name  Venue Latitude  \
# 0  4adcda9ff964a520654d21e3                   Stromovka       50.105098
# 1  4c5ed6b67735c9b617ca9272  Havlíčkovy sady (Grébovka)       50.068765
# 2  4b78047af964a5203bb22ee3               Letenské sady       50.096275
# 3  4affd3cdf964a5201c3a22e3                    Vyšehrad       50.064095
# 4  51c23e25498e8ef76e18c2c6      Vyhlídka Riegrovy sady       50.079692
# 5  5311ae7311d2b14c76832d24                   Naše maso       50.090763
# 6  4b464feef964a520451d26e3                       Kampa       50.083981
# 7  4bd473f46798ef3be09c618d            Vyhlídková cesta       50.085683
# 8  539842a2498ee08ed9e0b8ce                Mozzarellart       50.065568
# 9  4adcdaa0f964a5209a4d21e3               Riegrovy sady       50.080498
#
#    Venue Longitude  Venue Category
# 0        14.421840            Park
# 1        14.443674            Park
# 2        14.414406            Park
# 3        14.419387          Castle
# 4        14.440136  Scenic Lookout
# 5        14.426960         Butcher
# 6        14.407711            Park
# 7        14.391567  Scenic Lookout
# 8        14.439399     Cheese Shop
# 9        14.441271            Park

# %% [markdown]
# Quick inspection of the created dataframe shows that the top 100 local attractions were fetched correctly. Each record contains the ID, the attraction Name and Category, and the GPS coordinates.

# %% [markdown]
# ### The most popular hotels
#
# The endpoint _search_ is used to fetch the data, full API reference cen be found here: https://developer.foursquare.com/docs/api/venues/search
#
# The endpoint returns a JSON response with an array _venues_.
#
# The data which is the most interesting is:
# - Hotel ID
# - Hotel Name
# - Hotel Location: Latitude and Longitude
#
# This list is the list of *the most popular hotels*.

# %% [markdown]
# **Fetching and parsing the data**

# %%
HOTEL_CATEGORY_ID = '4bf58dd8d48988d1fa931735'
NUMBER_OF_HOTELS = 10

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&limit={}&near={}&categoryId={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    NUMBER_OF_HOTELS,
    DEFAULT_NEAR,
    HOTEL_CATEGORY_ID
)

results = requests.get(url).json()["response"]['venues']
        
data = [(
    v['id'],
    v['name'],
    v['location']['lat'],
    v['location']['lng']
) for v in results]

most_popular_hotels = pd.DataFrame(data, columns = [
  'Hotel Id', 
  'Hotel Name', 
  'Hotel Latitude', 
  'Hotel Longitude'
])

# %%
most_popular_hotels
# Out:
#                    Hotel Id                          Hotel Name  \
# 0  4adcda9bf964a5206d4c21e3                         Hotel Josef
# 1  5b486ba2666116002c231866                        Mama Shelter
# 2  4bc8f38f762beee162bc3d38           Hotel Don Giovanni Prague
# 3  4adcda9af964a520104c21e3          Hotel International Prague
# 4  4adcda9af964a5201e4c21e3                       Hilton Prague
# 5  4afa73f8f964a520e51722e3                     President Hotel
# 6  4c3eb2f3b8b4be9abb8accef  Holiday Inn Prague Congress Centre
# 7  4bdebff56316d13afbb7a011                 ibis Praha Old Town
# 8  4baccb7ef964a520da0c3be3               Park Inn Hotel Prague
# 9  579d0e32498e13267828248c                 Dancing House Hotel
#
#    Hotel Latitude  Hotel Longitude
# 0       50.089958        14.425959
# 1       50.102394        14.431907
# 2       50.078649        14.475701
# 3       50.109227        14.393567
# 4       50.093326        14.439827
# 5       50.092627        14.419600
# 6       50.061213        14.427136
# 7       50.089456        14.430903
# 8       50.068067        14.418326
# 9       50.075506        14.414191

# %% [markdown]
# Inspection of the data frame shows that 10 top hotels were fetched correctly and the hotels IDs, names and locations are available.

# %% [markdown]
# ### The most popular local attracation around the most popular hotels
#
# The endpoint _explore_ is used to fetch the data, full API reference cen be found here: https://developer.foursquare.com/docs/api/venues/explore
#
# This endpoint has been previously described for *the most popular attractions*. The difference here is that the HTTP call is made repeatedly for each hotel of *the most popular hotels* list.

# %% [markdown]
# **Fetching and parsing the data**

# %%
base_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&limit=100&radius=5000'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION
)

data = []

for _, hotel in most_popular_hotels.iterrows():
    url = base_url + '&ll={},{}'.format(
        hotel['Hotel Latitude'],
        hotel['Hotel Longitude']
    )
    
    results = requests.get(url).json()["response"]['groups'][0]['items']

    data.append([(
        hotel['Hotel Id'],
        hotel['Hotel Name'],
        v['venue']['id'],
        v['venue']['name'], 
        v['venue']['location']['lat'], 
        v['venue']['location']['lng'],  
        v['venue']['categories'][0]['name']        
    ) for v in results])
    
most_popular_attracations_around_most_popular_hotels = pd.DataFrame([item for data in data for item in data], columns = [
    'Hotel Id', 
    'Hotel Name', 
    'Venue Id', 
    'Venue Name', 
    'Venue Latitude', 
    'Venue Longitude', 
    'Venue Category'
])

# %%
most_popular_attracations_around_most_popular_hotels.shape
# Out:
# (1000, 7)

# %%
most_popular_attracations_around_most_popular_hotels.head(10)
# Out:
#                    Hotel Id   Hotel Name                  Venue Id  \
# 0  4adcda9bf964a5206d4c21e3  Hotel Josef  5311ae7311d2b14c76832d24
# 1  4adcda9bf964a5206d4c21e3  Hotel Josef  56447ad4498eee9ca211cc65
# 2  4adcda9bf964a5206d4c21e3  Hotel Josef  4adcda9bf964a5206d4c21e3
# 3  4adcda9bf964a5206d4c21e3  Hotel Josef  4b51eb43f964a520505b27e3
# 4  4adcda9bf964a5206d4c21e3  Hotel Josef  5662c71d498e4003dfb5de01
# 5  4adcda9bf964a5206d4c21e3  Hotel Josef  54141a6f498eda4d0b7ff98a
# 6  4adcda9bf964a5206d4c21e3  Hotel Josef  4adcda9af964a520234c21e3
# 7  4adcda9bf964a5206d4c21e3  Hotel Josef  521dccba498e314c4c758d38
# 8  4adcda9bf964a5206d4c21e3  Hotel Josef  52d501e3498e0793fa053add
# 9  4adcda9bf964a5206d4c21e3  Hotel Josef  4af47b29f964a520f1f221e3
#
#               Venue Name  Venue Latitude  Venue Longitude     Venue Category
# 0              Naše maso       50.090763        14.426960            Butcher
# 1                Bokovka       50.090859        14.426602           Wine Bar
# 2            Hotel Josef       50.089958        14.425959              Hotel
# 3       Yami Sushi House       50.089428        14.423481   Sushi Restaurant
# 4          onesip coffee       50.091269        14.425565        Coffee Shop
# 5  La Bottega Bistroteka       50.090789        14.427114             Bistro
# 6       Hotel Maximilian       50.091070        14.424626              Hotel
# 7             Pot au Feu       50.089119        14.426156  French Restaurant
# 8                Sisters       50.090752        14.426957     Sandwich Place
# 9   Ambiente Pizza Nuova       50.089426        14.427896        Pizza Place

# %%
most_popular_attracations_around_most_popular_hotels.tail(10)
# Out:
#                      Hotel Id           Hotel Name                  Venue Id  \
# 990  579d0e32498e13267828248c  Dancing House Hotel  528a5447498ef2ec6298376e
# 991  579d0e32498e13267828248c  Dancing House Hotel  4b9e87a6f964a5203aec36e3
# 992  579d0e32498e13267828248c  Dancing House Hotel  4b27fe6df964a520608d24e3
# 993  579d0e32498e13267828248c  Dancing House Hotel  4af47e99f964a52025f321e3
# 994  579d0e32498e13267828248c  Dancing House Hotel  4beeaade2c082d7fd4aa3042
# 995  579d0e32498e13267828248c  Dancing House Hotel  4bacf505f964a520031e3be3
# 996  579d0e32498e13267828248c  Dancing House Hotel  4b050f83f964a5201c5722e3
# 997  579d0e32498e13267828248c  Dancing House Hotel  4e254ab2d4c0d18a28a492e8
# 998  579d0e32498e13267828248c  Dancing House Hotel  4b9897a6f964a5200f4835e3
# 999  579d0e32498e13267828248c  Dancing House Hotel  4b51eb43f964a520505b27e3
#
#                                             Venue Name  Venue Latitude  \
# 990                                            IF Café       50.073390
# 991  Valdštejnská zahrada | Waldstein Garden (Valdš...       50.090156
# 992                             Brasileiro Restaurante       50.086428
# 993                                              Aromi       50.076352
# 994                                       Prašná brána       50.087215
# 995  Petřínská rozhledna | Petřín Lookout Tower (Pe...       50.083470
# 996                               Malostranské náměstí       50.088012
# 997              Energy HEAVEN - Studio Václav Krejčík       50.073775
# 998                                          Augustine       50.088686
# 999                                   Yami Sushi House       50.089428
#
#      Venue Longitude        Venue Category
# 990        14.435897                  Café
# 991        14.407898                Garden
# 992        14.427451  Brazilian Restaurant
# 993        14.436368    Italian Restaurant
# 994        14.427830         Historic Site
# 995        14.395105        Scenic Lookout
# 996        14.404428                 Plaza
# 997        14.437372           Yoga Studio
# 998        14.406111                 Hotel
# 999        14.423481      Sushi Restaurant

# %% [markdown]
# Quick look at the data shows that 1000 records are correctly present, as 10 hotels times 100 attractions gives that number. There is hotel and attracation details available in each tuple.
